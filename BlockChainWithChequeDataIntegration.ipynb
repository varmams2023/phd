# %% [markdown]
# <a href="https://colab.research.google.com/github/varmams2023/phd/blob/main/BlockChainWithChequeDataIntegration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install colorama  # Install the colorama library

import hashlib
import json
import pandas as pd
from time import time
from typing import List
from colorama import Fore, Style, init
from tqdm import tqdm  # For progress bar
from google.colab import drive

# Mount Google Drive to access the CSV file
drive.mount('/content/drive')

# Initialize colorama for colored outputs
init(autoreset=True)

# Block class to represent each block in the blockchain
class Block:
    def __init__(self, index, timestamp, cheque_data, previous_hash):
        self.index = index
        self.timestamp = timestamp
        self.cheque_data = cheque_data
        self.previous_hash = previous_hash
        self.hash = self.calculate_hash()

    def calculate_hash(self):
        block_string = json.dumps(self.__dict__, sort_keys=True)
        return hashlib.sha256(block_string.encode()).hexdigest()


# Blockchain class to handle blockchain operations
class Blockchain:
    def __init__(self):
        self.chain = []
        self.pending_cheques = []
        self.create_genesis_block()

    def create_genesis_block(self):
        # Manually construct the first block (genesis block)
        genesis_block = Block(0, time(), {"check_number": "0", "payee_name": "Genesis", "bank_name": "Genesis Bank", "account_number": "000000", "ifsc_code": "000000"}, "0")
        self.chain.append(genesis_block)

    def add_cheque(self, cheque_data):
        # Add cheque data to the blockchain
        previous_hash = self.chain[-1].hash
        new_block = Block(len(self.chain), time(), cheque_data, previous_hash)
        self.chain.append(new_block)
        self.pending_cheques = []  # Reset pending cheques after adding

    def add_cheques_to_blockchain(self, cheques: List[dict]):
        """Method to add multiple cheques to the blockchain"""
        for cheque in tqdm(cheques, desc="Adding Cheques to Blockchain", unit="cheque"):
            self.add_cheque(cheque)

    def validate_cheque(self, cheque_data):
        # Validate cheque information by checking the data's hash
        for block in self.chain:
            if block.cheque_data == cheque_data:
                return True  # Valid cheque data found
        return False

    def display_chain(self, num_blocks=15):
        # Display the blockchain, showing only a limited number of blocks
        print(f"\nDisplaying first {num_blocks} blocks from the blockchain:\n")
        for block in self.chain[:num_blocks]:
            print(f"\n{Fore.GREEN}Block #{block.index} ({Fore.CYAN}{block.timestamp}{Style.RESET_ALL})")
            print(f"{Fore.YELLOW}Check Number: {block.cheque_data['check_number']}")
            print(f"{Fore.YELLOW}Payee Name: {block.cheque_data['payee_name']}")
            print(f"{Fore.YELLOW}Bank Name: {block.cheque_data['bank_name']}")
            print(f"{Fore.YELLOW}Account Number: {block.cheque_data['account_number']}")
            print(f"{Fore.YELLOW}IFSC Code: {block.cheque_data['ifsc_code']}")
            print(f"{Fore.BLUE}Hash: {block.hash}\n")

    def count_blocks_by_bank(self):
        # Count the number of blocks by bank name
        bank_count = {}
        for block in self.chain:
            bank_name = block.cheque_data['bank_name']
            if bank_name in bank_count:
                bank_count[bank_name] += 1
            else:
                bank_count[bank_name] = 1
        return bank_count

    def total_blocks(self):
        # Return the total number of blocks in the blockchain
        return len(self.chain)


# Function to load cheque data from CSV file
def load_cheque_data_from_csv(file_path: str):
    # Read the CSV file into a pandas DataFrame
    df = pd.read_csv(file_path)

    # Ensure only relevant columns are selected
    cheque_data = df[['CheckNumber', 'AccountNumber', 'PayeeName', 'BankName', 'IFSCCode']]

    # Convert the DataFrame into a list of dictionaries
    cheque_data_list = cheque_data.rename(columns={
        'CheckNumber': 'check_number',
        'AccountNumber': 'account_number',
        'PayeeName': 'payee_name',
        'BankName': 'bank_name',
        'IFSCCode': 'ifsc_code'
    }).to_dict(orient='records')

    return cheque_data_list


# File path for the CSV in Google Drive
file_path = '/content/drive/MyDrive/phd/dataset/ChequeDataSetFull.csv'

# Initialize the blockchain
blockchain = Blockchain()

# Load cheque data from CSV
cheque_data_list = load_cheque_data_from_csv(file_path)

# Add cheques to the blockchain with progress feedback
blockchain.add_cheques_to_blockchain(cheque_data_list)

# Menu to display, add, or validate cheque
def display_menu():
    while True:
        print("\nMenu:")
        print("1. Print Blockchain")
        print("2. Add Block (Manually input cheque data)")
        print("3. Validate if Cheque is present")
        print("4. Print Count of Blocks by Bank")
        print("5. Exit")
        choice = input("Enter your choice (1/2/3/4/5): ")

        if choice == '1':
            # Take number of blocks to print as input
            num_blocks = int(input("Enter the number of blocks to display: "))
            blockchain.display_chain(num_blocks=num_blocks)

        elif choice == '2':
            # Manually input the fields for a new block
            check_number = input("Enter Check Number: ")
            payee_name = input("Enter Payee Name: ")
            bank_name = input("Enter Bank Name: ")
            account_number = input("Enter Account Number: ")
            ifsc_code = input("Enter IFSC Code: ")

            cheque_data = {
                'check_number': check_number,
                'payee_name': payee_name,
                'bank_name': bank_name,
                'account_number': account_number,
                'ifsc_code': ifsc_code
            }
            blockchain.add_cheque(cheque_data)
            print(Fore.GREEN + "Block added successfully!")

        elif choice == '3':
            # Manually input the fields for cheque validation
            check_number = input("Enter Check Number: ")
            payee_name = input("Enter Payee Name: ")
            bank_name = input("Enter Bank Name: ")
            account_number = input("Enter Account Number: ")
            ifsc_code = input("Enter IFSC Code: ")

            cheque_data = {
                'check_number': check_number,
                'payee_name': payee_name,
                'bank_name': bank_name,
                'account_number': account_number,
                'ifsc_code': ifsc_code
            }
            is_valid = blockchain.validate_cheque(cheque_data)
            if is_valid:
                print(Fore.GREEN + "Cheque is present in the blockchain.")
            else:
                print(Fore.RED + "Cheque is NOT present in the blockchain.")

        elif choice == '4':
            # Print count of blocks grouped by bank and total block count
            bank_count = blockchain.count_blocks_by_bank()
            total_blocks = blockchain.total_blocks()
            print(f"\nTotal Blocks in Blockchain: {total_blocks}")
            print("\nCount of Blocks by Bank:")
            for bank, count in bank_count.items():
                print(f"{Fore.YELLOW}{bank}: {count} blocks")

        elif choice == '5':
            print("Exiting...")
            break
        else:
            print(Fore.RED + "Invalid choice. Please try again.")

# Start the menu
display_menu()
# Out:
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (0.4.6)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Adding Cheques to Blockchain: 100%|██████████| 100000/100000 [00:02<00:00, 44144.56cheque/s]
# Menu:
# 1. Print Blockchain
# 2. Add Block (Manually input cheque data)
# 3. Validate if Cheque is present
# 4. Print Count of Blocks by Bank
# 5. Exit
#
# Total Blocks in Blockchain: 100001
#
# Count of Blocks by Bank:
# Genesis Bank: 1 blocks
# State Bank of India: 20113 blocks
# ICICI Bank: 19983 blocks
# Axis Bank: 20118 blocks
# HDFC Bank: 19894 blocks
# Bank of Baroda: 19892 blocks
#
# Menu:
# 1. Print Blockchain
# 2. Add Block (Manually input cheque data)
# 3. Validate if Cheque is present
# 4. Print Count of Blocks by Bank
# 5. Exit
#
# Displaying first 45 blocks from the blockchain:
#
#
# Block #0 (1734675378.8760662)
# Check Number: 0
# Payee Name: Genesis
# Bank Name: Genesis Bank
# Account Number: 000000
# IFSC Code: 000000
# Hash: a9fe48d962416c747c62b0bb80bc829315205e430d07e20e3ca5a9b03def4597
#
#
# Block #1 (1734675379.549344)
# Check Number: 65782867
# Payee Name: Devika Reddy
# Bank Name: State Bank of India
# Account Number: 3156841378
# IFSC Code: SBIN0008572
# Hash: c034d7ed2514f2b8cf5ebffde327bd6110ed107670cb345e5079f4cc7186bc6c
#
#
# Block #2 (1734675379.5494483)
# Check Number: 56855036
# Payee Name: Aanya Sharma
# Bank Name: State Bank of India
# Account Number: 7130589870
# IFSC Code: SBIN0008316
# Hash: c6e831931e1956039fc3a01e998badd8470a6ea41c1e5f0138fda28a527742f0
#
#
# Block #3 (1734675379.5494835)
# Check Number: 56982282
# Payee Name: Arjun Chatterjee
# Bank Name: State Bank of India
# Account Number: 6628410133
# IFSC Code: SBIN0002241
# Hash: 239c777b7871416457e4a3a0b00e37c2957cdcb9ff062883e0bf558f156b4222
#
#
# Block #4 (1734675379.5495124)
# Check Number: 21181788
# Payee Name: Ishan Joshi
# Bank Name: ICICI Bank
# Account Number: 1985965527
# IFSC Code: ICIC0005164
# Hash: 86b9f1f538e77070eaab9b41ceb858c4de81bc6e044b866397e1de89657bc11a
#
#
# Block #5 (1734675379.549539)
# Check Number: 13415092
# Payee Name: Arjun Das
# Bank Name: Axis Bank
# Account Number: 3275070587
# IFSC Code: UTIB0001101
# Hash: a8fabbdb77c05d4c186bf507a1532275470dd259c77ac7bfd20ffe96924c29e9
#
#
# Block #6 (1734675379.5495648)
# Check Number: 35888921
# Payee Name: Kavya Das
# Bank Name: HDFC Bank
# Account Number: 5372136052
# IFSC Code: HDFC0007956
# Hash: 717cad2fac60f351571aec70bc6818fee93849f582f19c6dcbb051decab76f06
#
#
# Block #7 (1734675379.5495892)
# Check Number: 26835830
# Payee Name: Kavya Kumar
# Bank Name: State Bank of India
# Account Number: 6946801258
# IFSC Code: SBIN0005529
# Hash: 27f6bf9fcedca42db893ea30929efd947db9a502f4d0b3e57dd21a064a6796ce
#
#
# Block #8 (1734675379.5496109)
# Check Number: 93510762
# Payee Name: Devika Kumar
# Bank Name: Axis Bank
# Account Number: 4633964845
# IFSC Code: UTIB0007018
# Hash: dbcfaad0061f6f0c5608c61da25102b457be5a2ba210a3e53914c6f8f81ced69
#
#
# Block #9 (1734675379.5496323)
# Check Number: 96419575
# Payee Name: Ananya Rao
# Bank Name: State Bank of India
# Account Number: 5021220853
# IFSC Code: SBIN0004938
# Hash: a8a9bdc727f0c9ba43943bd9ffcc1ff27739e93d2236f3e3bef0bf1669f38cd3
#
#
# Block #10 (1734675379.5496514)
# Check Number: 91190292
# Payee Name: Arjun Joshi
# Bank Name: ICICI Bank
# Account Number: 9908686457
# IFSC Code: ICIC0009532
# Hash: 8f25dc92717caf0ab40022e660da83b4054a71b80df8d045dd5b2d14fce069f0
#
#
# Block #11 (1734675379.5496693)
# Check Number: 31732483
# Payee Name: Aanya Sharma
# Bank Name: State Bank of India
# Account Number: 8368243690
# IFSC Code: SBIN0006154
# Hash: 4ba0da3193fcdeaa0a4690c9f611603ce0e76c0cad2ac9546f757e11c349353e
#
#
# Block #12 (1734675379.549688)
# Check Number: 76837383
# Payee Name: Aarav Rao
# Bank Name: Bank of Baroda
# Account Number: 5282836349
# IFSC Code: BARB0006754
# Hash: def88a62b552340563c5c6c99ef786bd90170a923443da96c29864273923b0da
#
#
# Block #13 (1734675379.5497053)
# Check Number: 88458551
# Payee Name: Aanya Das
# Bank Name: HDFC Bank
# Account Number: 9058663117
# IFSC Code: HDFC0004253
# Hash: e57e1befd55bad64887cc2de622d78c52c619494c9cbfbc6f05d852b6a91dbd4
#
#
# Block #14 (1734675379.5497227)
# Check Number: 88509749
# Payee Name: Ananya Gupta
# Bank Name: Axis Bank
# Account Number: 7903030762
# IFSC Code: UTIB0004862
# Hash: 98c952de3f3f11fbc34df207458f56d72c7ba7dd888148064df296e79dfc5e6b
#
#
# Block #15 (1734675379.5497394)
# Check Number: 5081505
# Payee Name: Aanya Sharma
# Bank Name: Bank of Baroda
# Account Number: 4128674367
# IFSC Code: BARB0008161
# Hash: 058981c5f5b4a8f95b1e3f514041d5dc97875ae3efed1f9f1f134fab98f88351
#
#
# Block #16 (1734675379.5497568)
# Check Number: 14053367
# Payee Name: Aarav Gupta
# Bank Name: HDFC Bank
# Account Number: 7767864317
# IFSC Code: HDFC0006367
# Hash: 5337afb32a87f4994fdf218d73ec624b61875436c0b0d272dbdccb80aedb486d
#
#
# Block #17 (1734675379.5497756)
# Check Number: 85752971
# Payee Name: Ananya Chatterjee
# Bank Name: Axis Bank
# Account Number: 3135266722
# IFSC Code: UTIB0007837
# Hash: 25c8e6053ab3ae04d6e98ed51f8c17921a69d9c37e9c8fabd880c98e7a927f1f
#
#
# Block #18 (1734675379.5497947)
# Check Number: 4621373
# Payee Name: Aarav Reddy
# Bank Name: Bank of Baroda
# Account Number: 1550831554
# IFSC Code: BARB0002467
# Hash: eddc1166dab5d110c43ecb8270932d2a9b8549a394e414fb1bdab438ac2a6d55
#
#
# Block #19 (1734675379.5498145)
# Check Number: 3444769
# Payee Name: Aanya Reddy
# Bank Name: HDFC Bank
# Account Number: 9902247423
# IFSC Code: HDFC0005621
# Hash: ece6251fd24288fb3b1e4b2e02098a0b49ab7683605898e766cf2c5aeee9c7ab
#
#
# Block #20 (1734675379.5498357)
# Check Number: 98850923
# Payee Name: Avani Reddy
# Bank Name: State Bank of India
# Account Number: 8635812749
# IFSC Code: SBIN0007041
# Hash: dfcb982410cc941cf7f867db1774685787501ecbedb996b29389dc602b746943
#
#
# Block #21 (1734675379.5498571)
# Check Number: 76993497
# Payee Name: Ishan Das
# Bank Name: State Bank of India
# Account Number: 8199536154
# IFSC Code: SBIN0002250
# Hash: 27aa01f0cd0c73791ef05b28badd733bb266fbbd8d0ea8612fcf168cb2b3c75c
#
#
# Block #22 (1734675379.5498765)
# Check Number: 30449564
# Payee Name: Arjun Das
# Bank Name: Axis Bank
# Account Number: 8082539420
# IFSC Code: UTIB0003720
# Hash: 4585f473045d97b6a8dc61e0b54fa57b98e1b974dd034367a289d7e02b329f5a
#
#
# Block #23 (1734675379.5499034)
# Check Number: 99152376
# Payee Name: Aarav Das
# Bank Name: State Bank of India
# Account Number: 4986278225
# IFSC Code: SBIN0002190
# Hash: 566985d01ac68cd307b634dd4a51ae3d4e415c339ea7ec697b50764ec93532e7
#
#
# Block #24 (1734675379.5499225)
# Check Number: 42960080
# Payee Name: Ishan Patel
# Bank Name: State Bank of India
# Account Number: 2716835957
# IFSC Code: SBIN0005215
# Hash: bd9a77afcdfb4c9cd1e271beade380c6ef7dc49bb99ffefc101bcef2cba44a5d
#
#
# Block #25 (1734675379.5499432)
# Check Number: 77851354
# Payee Name: Kavya Joshi
# Bank Name: ICICI Bank
# Account Number: 8636526722
# IFSC Code: ICIC0007150
# Hash: 09ac9bf3df181ffdf497b9de7e501d262a17668c0989ed4fbd4c3c49aadfa3e5
#
#
# Block #26 (1734675379.5499651)
# Check Number: 62350665
# Payee Name: Ishan Chatterjee
# Bank Name: State Bank of India
# Account Number: 7464472800
# IFSC Code: SBIN0009373
# Hash: 674bbf70a677a02bcafbde8d32dabbdad6a93721b54511a36c56802302c7be8d
#
#
# Block #27 (1734675379.5499864)
# Check Number: 66309791
# Payee Name: Nikhil Sharma
# Bank Name: ICICI Bank
# Account Number: 6021322148
# IFSC Code: ICIC0002737
# Hash: d453d1556598643222e3e7a66007691be8ead45c19ee74d2e3b4754a3d4c7039
#
#
# Block #28 (1734675379.5500064)
# Check Number: 46892155
# Payee Name: Aditya Sharma
# Bank Name: HDFC Bank
# Account Number: 1241681003
# IFSC Code: HDFC0004177
# Hash: 45efb40cbc334da8ae95ab34e0330fc2444262cb6eb1330e0995ed02a8940f59
#
#
# Block #29 (1734675379.5500264)
# Check Number: 21598555
# Payee Name: Arjun Das
# Bank Name: State Bank of India
# Account Number: 6651196128
# IFSC Code: SBIN0003404
# Hash: 6c15d5b5d3c0b136c49c8e1c649c124f1b51a0405c30d8f53dde51b0c2446700
#
#
# Block #30 (1734675379.5500543)
# Check Number: 97217135
# Payee Name: Ishan Patel
# Bank Name: Axis Bank
# Account Number: 8805249122
# IFSC Code: UTIB0007229
# Hash: 7c4385f9167701d2045b88e594c58012fc534ab44de4b0d7811c95f403e3ce10
#
#
# Block #31 (1734675379.5500774)
# Check Number: 60321198
# Payee Name: Ishan Sharma
# Bank Name: Bank of Baroda
# Account Number: 2751683744
# IFSC Code: BARB0008333
# Hash: bf0a66fc41d4f1a7da3ce1e0757bd061a33469b94c4e86d52e19572790fea16f
#
#
# Block #32 (1734675379.550098)
# Check Number: 79857501
# Payee Name: Arjun Rao
# Bank Name: ICICI Bank
# Account Number: 8913643888
# IFSC Code: ICIC0004060
# Hash: 81aefdfbb6e0a7737498dc5d83341433f1e74a3deff3e626d92f86f91576962f
#
#
# Block #33 (1734675379.5501192)
# Check Number: 16961870
# Payee Name: Kavya Gupta
# Bank Name: Axis Bank
# Account Number: 1827801700
# IFSC Code: UTIB0003342
# Hash: f6d4f5b3f86a16b8f1d6fc3b1176399fcc9e35e9475fe4eac09bc05b01a1a32e
#
#
# Block #34 (1734675379.5501413)
# Check Number: 52386002
# Payee Name: Arjun Chatterjee
# Bank Name: State Bank of India
# Account Number: 7580067209
# IFSC Code: SBIN0009369
# Hash: 70ef1f1d2e8dc99a375930414adecb4b0e77ceb1b6eb6538fa0980d347411a71
#
#
# Block #35 (1734675379.5501642)
# Check Number: 32149003
# Payee Name: Aanya Gupta
# Bank Name: Axis Bank
# Account Number: 3494402030
# IFSC Code: UTIB0007508
# Hash: b9af0b823cfc6547634c9fb19acad2a55031c89a453618d16120b6fc72d57eba
#
#
# Block #36 (1734675379.5501857)
# Check Number: 61236438
# Payee Name: Avani Chatterjee
# Bank Name: State Bank of India
# Account Number: 8133469253
# IFSC Code: SBIN0005507
# Hash: 8a71b31086540a46de869fad89da23039b23d391027f041687d5faf66994b13a
#
#
# Block #37 (1734675379.550206)
# Check Number: 62294931
# Payee Name: Kavya Kumar
# Bank Name: Axis Bank
# Account Number: 3362627391
# IFSC Code: UTIB0003785
# Hash: 6bb2d610556038e6dc734d5ebc8ee406fb5749347cdd1182177be4dd02b3182f
#
#
# Block #38 (1734675379.5502279)
# Check Number: 65385250
# Payee Name: Nikhil Patel
# Bank Name: HDFC Bank
# Account Number: 3755609982
# IFSC Code: HDFC0009483
# Hash: 6c14745c6c102636f0d7b80f70b53c092ad357bc5f22f6f3b1aabb590d2ac088
#
#
# Block #39 (1734675379.5502708)
# Check Number: 69637252
# Payee Name: Nikhil Patel
# Bank Name: Axis Bank
# Account Number: 2873079124
# IFSC Code: UTIB0008842
# Hash: 58e7abeea6b1b5f1d3d7b410de3c9cca17b0ea4b43890166d12f7dba750eca13
#
#
# Block #40 (1734675379.5502934)
# Check Number: 59348434
# Payee Name: Avani Joshi
# Bank Name: Bank of Baroda
# Account Number: 5340153384
# IFSC Code: BARB0009190
# Hash: 85a6e98d65945cb153fa7f5fb9650f9aed30150fc3199d6c1a2a9e5a619d98e9
#
#
# Block #41 (1734675379.5503128)
# Check Number: 61406900
# Payee Name: Devika Kumar
# Bank Name: HDFC Bank
# Account Number: 1388277220
# IFSC Code: HDFC0007245
# Hash: f7b771e4165897d17a6b93a123fb013b638c8d75f25012208a43ebcb8a601179
#
#
# Block #42 (1734675379.5503335)
# Check Number: 55931368
# Payee Name: Nikhil Sharma
# Bank Name: Bank of Baroda
# Account Number: 4187055047
# IFSC Code: BARB0007476
# Hash: 057b4a0215913eb1f25cf4cd28d47ecf0c1afc56c3f28f4cb6ccafdc461da06f
#
#
# Block #43 (1734675379.5503535)
# Check Number: 11059014
# Payee Name: Nikhil Kumar
# Bank Name: Axis Bank
# Account Number: 6953064326
# IFSC Code: UTIB0001623
# Hash: 8b86cc95a5ce5af33fba023d1618d24e1e178aa7c46787d08950883c18a44aab
#
#
# Block #44 (1734675379.5503829)
# Check Number: 57072561
# Payee Name: Aditya Reddy
# Bank Name: Bank of Baroda
# Account Number: 1224916950
# IFSC Code: BARB0008376
# Hash: 529ced275dda75c8cd09930b3004a4ababdf732b61d2b5cc75f865ddcf3f8533
#
#
# Menu:
# 1. Print Blockchain
# 2. Add Block (Manually input cheque data)
# 3. Validate if Cheque is present
# 4. Print Count of Blocks by Bank
# 5. Exit
